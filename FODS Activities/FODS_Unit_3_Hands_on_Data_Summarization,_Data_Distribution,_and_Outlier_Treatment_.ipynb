# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijay16835/FODS-DSA0404/blob/main/FODS_Unit_3_Hands_on_Data_Summarization%2C_Data_Distribution%2C_and_Outlier_Treatment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Create a sample employee dataset for demonstration
data = {
    'EmployeeID': range(1, 11),
    'FirstName': ['John', 'Jane', 'Mike', 'Emily', 'Chris', 'Anna', 'David', 'Sarah', 'James', 'Laura'],
    'LastName': ['Doe', 'Smith', 'Johnson', 'Davis', 'Brown', 'Wilson', 'Moore', 'Taylor', 'Anderson', 'Thomas'],
    'Age': [30, 24, 45, 32, 28, 35, 50, 29, 41, 33],
    'Department': ['Sales', 'Marketing', 'IT', 'HR', 'Sales', 'IT', 'Marketing', 'HR', 'Sales', 'IT'],
    'Salary': [50000, 48000, 75000, 60000, 52000, 70000, 65000, 58000, 80000, 68000],
    'HireDate': pd.to_datetime(['2018-01-15', '2020-03-20', '2010-06-01', '2019-11-10', '2021-09-01', '2015-02-28', '2005-07-01', '2022-04-15', '2013-08-01', '2017-01-01']),
    'PerformanceScore': [85, 92, 78, 88, 90, 82, 75, 95, 80, 87],
    'ManagerID': [2, np.nan, 2, 4, 2, 6, 4, 4, np.nan, 6]
}
df = pd.DataFrame(data)

# Introduce some missing values for demonstration
df.loc[0, 'Salary'] = np.nan
df.loc[3, 'Department'] = np.nan
df.loc[7, 'PerformanceScore'] = np.nan

print("### Employee Dataset Summary ###\n")

# 1. Number of rows and columns
print(f"Number of Rows: {df.shape[0]}")
print(f"Number of Columns: {df.shape[1]}\n")

# 2. Data types
print("Data Types:\n")
display(df.dtypes.to_frame(name='Data Type'))
print("\n")

# 3. Missing values
print("Missing Values:\n")
display(df.isnull().sum().to_frame(name='Missing Count'))
print("\n")

# 4. Statistical summary
print("Statistical Summary (Numerical and Categorical):\n")
display(df.describe(include='all'))
# Out:
# ### Employee Dataset Summary ###
#
# Number of Rows: 10
# Number of Columns: 9
#
# Data Types:
#                        Data Type
# EmployeeID                 int64
# FirstName                 object
# LastName                  object
# Age                        int64
# Department                object
# Salary                   float64
# HireDate          datetime64[ns]
# PerformanceScore         float64
# ManagerID                float64
# Missing Values:
#                   Missing Count
# EmployeeID                    0
# FirstName                     0
# LastName                      0
# Age                           0
# Department                    1
# Salary                        1
# HireDate                      0
# PerformanceScore              1
# ManagerID                     2
# Statistical Summary (Numerical and Categorical):
#         EmployeeID FirstName LastName        Age Department   Salary  \
# count     10.00000        10       10  10.000000          9      9.0
# unique         NaN        10       10        NaN          4      NaN
# top            NaN      John      Doe        NaN      Sales      NaN
# freq           NaN         1        1        NaN          3      NaN
# mean       5.50000       NaN      NaN  34.700000        NaN  64000.0
# min        1.00000       NaN      NaN  24.000000        NaN  48000.0
# 25%        3.25000       NaN      NaN  29.250000        NaN  58000.0
# 50%        5.50000       NaN      NaN  32.500000        NaN  65000.0
# 75%        7.75000       NaN      NaN  39.500000        NaN  70000.0
# max       10.00000       NaN      NaN  50.000000        NaN  80000.0
# std        3.02765       NaN      NaN   8.192815        NaN  10500.0
#
#                    HireDate  PerformanceScore  ManagerID
# count                    10          9.000000   8.000000
# unique                  NaN               NaN        NaN
# top                     NaN               NaN        NaN
# freq                    NaN               NaN        NaN
# mean    2016-05-16 00:00:00         84.111111   3.750000
# min     2005-07-01 00:00:00         75.000000   2.000000
# 25%     2013-12-23 00:00:00         80.000000   2.000000
# 50%     2017-07-09 12:00:00         85.000000   4.000000
# 75%     2020-02-16 06:00:00         88.000000   4.500000
# max     2022-04-15 00:00:00         92.000000   6.000000
# std                     NaN          5.732461   1.669046

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# 1. Generate a sample dataset of house prices
# Let's create a synthetic dataset that is slightly skewed to the right
np.random.seed(42) # for reproducibility
house_prices = np.concatenate([
    np.random.normal(loc=250000, scale=50000, size=700), # Majority of houses
    np.random.normal(loc=600000, scale=100000, size=200), # More expensive houses
    np.random.normal(loc=150000, scale=30000, size=100) # Less expensive houses
])

# Ensure all prices are positive
house_prices = house_prices[house_prices > 0]

# Create a Pandas Series for easy handling
house_prices_series = pd.Series(house_prices, name='House Prices')

print(f"Generated {len(house_prices_series)} sample house prices.")
print(f"Minimum Price: ${house_prices_series.min():,.2f}")
print(f"Maximum Price: ${house_prices_series.max():,.2f}")
print(f"Mean Price: ${house_prices_series.mean():,.2f}\n")

# 2. Plot the histogram of house prices
plt.figure(figsize=(10, 6))
sns.histplot(house_prices_series, bins=50, kde=True, color='skyblue', edgecolor='black')
plt.title('Distribution of House Prices')
plt.xlabel('House Price ($)')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# 3. Calculate skewness
skewness_value = skew(house_prices_series)
print(f"\nSkewness of House Prices: {skewness_value:.4f}")
# Out:
# Generated 1000 sample house prices.
# Minimum Price: $77,283.62
# Maximum Price: $863,238.21
# Mean Price: $312,023.34
# Skewness of House Prices: 1.3887

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Create a sample list of student grades
grades = [
    'A', 'B', 'C', 'A', 'D', 'B', 'A', 'F', 'C', 'B',
    'A', 'C', 'B', 'D', 'A', 'A', 'C', 'B', 'E', 'B',
    'A', 'C', 'F', 'B', 'D', 'C', 'A', 'B', 'A', 'C'
]

# Convert the list to a Pandas Series for easier frequency calculation
grades_series = pd.Series(grades, name='Grades')

# 2. Calculate the frequency distribution of students' grades
frequency_distribution = grades_series.value_counts().sort_index()

print("### Frequency Distribution of Student Grades ###\n")
print(frequency_distribution)
print("\n")

# 3. Display the results using a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=frequency_distribution.index, y=frequency_distribution.values, palette='viridis')
plt.title('Frequency Distribution of Student Grades')
plt.xlabel('Grade')
plt.ylabel('Number of Students')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# ### Frequency Distribution of Student Grades ###
#
# Grades
# A    9
# B    8
# C    7
# D    3
# E    1
# F    2
# Name: count, dtype: int64
# /tmp/ipykernel_512/1146311931.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequency_distribution.index, y=frequency_distribution.values, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a box plot for the 'Salary' column
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Salary'], palette='pastel')
plt.title('Box Plot of Employee Salaries')
plt.ylabel('Salary ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_512/468544550.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=df['Salary'], palette='pastel')

# %%
import pandas as pd
import numpy as np

# 1. Create a sample dataset of student marks
# Let's include some potential outliers for demonstration
marks = [
    65, 70, 72, 75, 78, 80, 81, 83, 85, 88,
    90, 92, 95, 98, 100, # Regular marks
    30, 45, # Low outliers
    105, 110 # High outliers (e.g., bonus points, data entry errors)
]

marks_series = pd.Series(marks, name='Student Marks')

print("### Student Marks Data ###\n")
print(marks_series)
print("\n")

# 2. Calculate the Interquartile Range (IQR)
Q1 = marks_series.quantile(0.25)
Q3 = marks_series.quantile(0.75)
IQR = Q3 - Q1

print(f"First Quartile (Q1): {Q1}")
print(f"Third Quartile (Q3): {Q3}")
print(f"Interquartile Range (IQR): {IQR}\n")

# 3. Define outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower Bound for Outliers: {lower_bound}")
print(f"Upper Bound for Outliers: {upper_bound}\n")

# 4. Detect outliers
outliers = marks_series[(marks_series < lower_bound) | (marks_series > upper_bound)]

if not outliers.empty:
    print("### Detected Outliers ###\n")
    print(outliers)
else:
    print("No outliers detected in the student marks using the IQR method.")

# Optional: Visualize with a box plot to confirm
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(y=marks_series, palette='coolwarm')
plt.title('Box Plot of Student Marks with Outliers')
plt.ylabel('Marks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# ### Student Marks Data ###
#
# 0      65
# 1      70
# 2      72
# 3      75
# 4      78
# 5      80
# 6      81
# 7      83
# 8      85
# 9      88
# 10     90
# 11     92
# 12     95
# 13     98
# 14    100
# 15     30
# 16     45
# 17    105
# 18    110
# Name: Student Marks, dtype: int64
#
#
# First Quartile (Q1): 73.5
# Third Quartile (Q3): 93.5
# Interquartile Range (IQR): 20.0
#
# Lower Bound for Outliers: 43.5
# Upper Bound for Outliers: 123.5
#
# ### Detected Outliers ###
#
# 15    30
# Name: Student Marks, dtype: int64
# /tmp/ipykernel_512/4201509680.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=marks_series, palette='coolwarm')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Create a sample sales dataset with some outliers
np.random.seed(42) # for reproducibility
sales_data = np.concatenate([
    np.random.normal(loc=1000, scale=200, size=90), # Regular sales
    np.random.normal(loc=5000, scale=500, size=5),  # High outliers
    np.random.normal(loc=100, scale=30, size=5)   # Low outliers
])

sales_series = pd.Series(sales_data, name='Daily Sales ($)')

print("### Original Sales Data (with potential outliers) ###\n")
display(sales_series.describe())

# Visualize original data
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(sales_series, bins=30, kde=True, color='purple', edgecolor='black')
plt.title('Original Sales Distribution')
plt.xlabel('Sales Amount ($)')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.boxplot(y=sales_series, color='purple') # Changed palette to color
plt.title('Original Sales Box Plot')
plt.ylabel('Sales Amount ($)')
plt.tight_layout()
plt.show()

# 2. Calculate the Interquartile Range (IQR) for sales data
Q1_sales = sales_series.quantile(0.25)
Q3_sales = sales_series.quantile(0.75)
IQR_sales = Q3_sales - Q1_sales

print(f"\nFirst Quartile (Q1): {Q1_sales:.2f}")
print(f"Third Quartile (Q3): {Q3_sales:.2f}")
print(f"Interquartile Range (IQR): {IQR_sales:.2f}\n")

# 3. Define outlier bounds
lower_bound_sales = Q1_sales - 1.5 * IQR_sales
upper_bound_sales = Q3_sales + 1.5 * IQR_sales

print(f"Lower Bound for Outliers: {lower_bound_sales:.2f}")
print(f"Upper Bound for Outliers: {upper_bound_sales:.2f}\n")

# 4. Identify outliers
outliers_sales = sales_series[
    (sales_series < lower_bound_sales) |
    (sales_series > upper_bound_sales)
]

print("### Detected Outliers in Sales Data ###\n")
if not outliers_sales.empty:
    display(outliers_sales)
else:
    print("No outliers detected in the sales data using the IQR method.")

# 5. Remove outliers from the dataset
cleaned_sales_series = sales_series[
    (sales_series >= lower_bound_sales) &
    (sales_series <= upper_bound_sales)
]

print("\n### Cleaned Sales Data (Outliers Removed) ###\n")
display(cleaned_sales_series.describe())

# Visualize cleaned data
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(cleaned_sales_series, bins=30, kde=True, color='green', edgecolor='black')
plt.title('Cleaned Sales Distribution')
plt.xlabel('Sales Amount ($)')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.boxplot(y=cleaned_sales_series, color='green') # Changed palette to color
plt.title('Cleaned Sales Box Plot')
plt.ylabel('Sales Amount ($)')
plt.tight_layout()
plt.show()
# Out:
# ### Original Sales Data (with potential outliers) ###
# count     100.000000
# mean     1135.093276
# std       923.522556
# min        56.094552
# 25%       862.469490
# 50%       974.608742
# 75%      1124.135870
# max      5484.322495
# Name: Daily Sales ($), dtype: float64
# First Quartile (Q1): 862.47
# Third Quartile (Q3): 1124.14
# Interquartile Range (IQR): 261.67
#
# Lower Bound for Outliers: 469.97
# Upper Bound for Outliers: 1516.64
#
# ### Detected Outliers in Sales Data ###
# 90    5048.538775
# 91    5484.322495
# 92    4648.973453
# 93    4836.168927
# 94    4803.945923
# 95      56.094552
# 96     108.883608
# 97     107.831658
# 98     100.153404
# 99      92.962386
# Name: Daily Sales ($), dtype: float64
# ### Cleaned Sales Data (Outliers Removed) ###
# count      90.000000
# mean      980.238360
# std       186.989751
# min       476.050979
# 25%       879.712074
# 50%       974.608742
# 75%      1101.825823
# max      1370.455637
# Name: Daily Sales ($), dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

print("### Starting Titanic Dataset EDA ###\n")

# 1. Download and Load Titanic Dataset
try:
    df = sns.load_dataset('titanic')
    print("Titanic dataset loaded successfully.\n")
except Exception as e:
    print(f"Error loading dataset: {e}. Please ensure you have an internet connection or the dataset is available locally.")
    # Fallback if seaborn fails to load directly (though it's usually reliable)
    # You might consider providing a URL for direct download if this is a common issue
    df = pd.DataFrame() # Create an empty dataframe to prevent further errors if loading fails

if not df.empty:
    # Create a copy to work with, preserving the original if needed
    titanic_df = df.copy()

    print("### Dataset Information ###\n")
    # Display dataset information
    print("First 5 rows of the dataset:")
    display(titanic_df.head())
    print(f"\nDataset Shape: {titanic_df.shape[0]} rows, {titanic_df.shape[1]} columns")
    print("\nDetailed info:")
    titanic_df.info()

    print("\n### Missing Values Analysis ###\n")
    # Finding missing values
    missing_values = titanic_df.isnull().sum()
    missing_percentage = (titanic_df.isnull().sum() / len(titanic_df)) * 100
    missing_info = pd.DataFrame({
        'Missing Count': missing_values,
        'Missing Percentage': missing_percentage
    })
    display(missing_info[missing_info['Missing Count'] > 0].sort_values(by='Missing Count', ascending=False))

    # Handling missing values
    # 'age': Impute with median as it's numerical and can be skewed
    titanic_df['age'].fillna(titanic_df['age'].median(), inplace=True)
    # 'embarked': Impute with mode as it's categorical
    titanic_df['embarked'].fillna(titanic_df['embarked'].mode()[0], inplace=True)
    # 'deck': Too many missing values (77%), drop the column
    titanic_df.drop('deck', axis=1, inplace=True)
    # 'fare': Impute with median for any potential missing values (though typically none in titanic dataset)
    titanic_df['fare'].fillna(titanic_df['fare'].median(), inplace=True)

    print("\nMissing values after imputation/dropping:\n")
    display(titanic_df.isnull().sum().to_frame(name='Remaining Missing Count'))

    print("\n### Descriptive Statistics ###\n")
    # Computing descriptive statistics
    display(titanic_df.describe(include='all'))

    print("\n### Data Visualization ###\n")
    # Identify numerical and categorical columns for plotting
    numerical_cols = titanic_df.select_dtypes(include=np.number).columns.tolist()
    categorical_cols = titanic_df.select_dtypes(exclude=np.number).columns.tolist()

    # Plotting Histograms for numerical columns
    print("Histograms for Numerical Features:\n")
    plt.figure(figsize=(15, 10))
    for i, col in enumerate(numerical_cols):
        plt.subplot(3, 3, i + 1) # Adjust subplot grid as needed
        sns.histplot(titanic_df[col], kde=True, bins=30)
        plt.title(f'Distribution of {col}')
    plt.tight_layout()
    plt.show()

    # Plotting Box Plots for numerical columns
    print("\nBox Plots for Numerical Features (Outlier Detection Visualization):\n")
    plt.figure(figsize=(15, 10))
    for i, col in enumerate(numerical_cols):
        plt.subplot(3, 3, i + 1) # Adjust subplot grid as needed
        sns.boxplot(y=titanic_df[col])
        plt.title(f'Box Plot of {col}')
    plt.tight_layout()
    plt.show()

    print("\n### Outlier Detection and Removal (using IQR method) ###\n")

    def detect_and_remove_outliers_iqr(df, column):
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
        df_cleaned = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

        print(f"\nColumn: {column}")
        print(f"  Q1: {Q1:.2f}, Q3: {Q3:.2f}, IQR: {IQR:.2f}")
        print(f"  Lower Bound: {lower_bound:.2f}, Upper Bound: {upper_bound:.2f}")
        print(f"  Number of outliers detected: {len(outliers)}")
        if not outliers.empty:
            print("  Sample outliers:\n")
            display(outliers.head())
        return df_cleaned, outliers

    # Apply outlier detection and removal to key numerical columns
    cleaned_titanic_df = titanic_df.copy()
    columns_to_check_outliers = ['age', 'fare', 'sibsp', 'parch'] # Exclude 'pclass' as it's more categorical

    all_outliers = pd.DataFrame()

    for col in columns_to_check_outliers:
        initial_rows = len(cleaned_titanic_df)
        cleaned_titanic_df, current_outliers = detect_and_remove_outliers_iqr(cleaned_titanic_df, col)
        all_outliers = pd.concat([all_outliers, current_outliers])
        print(f"  {initial_rows - len(cleaned_titanic_df)} rows removed for outliers in '{col}'. Remaining rows: {len(cleaned_titanic_df)}")

    print(f"\nTotal rows before outlier removal: {len(titanic_df)}")
    print(f"Total rows after outlier removal: {len(cleaned_titanic_df)}")
    print(f"Number of unique outliers identified across selected columns: {len(all_outliers.drop_duplicates())}\n")

    # Visualize distributions after outlier removal
    print("Distributions after Outlier Removal:\n")
    plt.figure(figsize=(15, 10))
    for i, col in enumerate(columns_to_check_outliers):
        if col in cleaned_titanic_df.columns: # Check if column still exists after previous outlier removal steps
            plt.subplot(2, 2, i + 1)
            sns.histplot(cleaned_titanic_df[col], kde=True, bins=30, color='green')
            plt.title(f'Cleaned Distribution of {col}')
    plt.tight_layout()
    plt.show()

    print("\n### Saving Cleaned Dataset ###\n")
    # Saving the cleaned dataset
    output_filename = 'titanic_cleaned.csv'
    cleaned_titanic_df.to_csv(output_filename, index=False)
    print(f"Cleaned Titanic dataset saved to '{output_filename}'")

    print("\n### EDA Complete ###")
else:
    print("Cannot proceed with EDA as the dataset failed to load.")
# Out:
# ### Starting Titanic Dataset EDA ###
#
# Titanic dataset loaded successfully.
#
# ### Dataset Information ###
#
# First 5 rows of the dataset:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# Dataset Shape: 891 rows, 15 columns
#
# Detailed info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
#
# ### Missing Values Analysis ###
#              Missing Count  Missing Percentage
# deck                   688           77.216611
# age                    177           19.865320
# embarked                 2            0.224467
# embark_town              2            0.224467
# Missing values after imputation/dropping:
# /tmp/ipykernel_512/1289441994.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['age'].fillna(titanic_df['age'].median(), inplace=True)
# /tmp/ipykernel_512/1289441994.py:45: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['embarked'].fillna(titanic_df['embarked'].mode()[0], inplace=True)
# /tmp/ipykernel_512/1289441994.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['fare'].fillna(titanic_df['fare'].median(), inplace=True)
#              Remaining Missing Count
# survived                           0
# pclass                             0
# sex                                0
# age                                0
# sibsp                              0
# parch                              0
# fare                               0
# embarked                           0
# class                              0
# who                                0
# adult_male                         0
# embark_town                        2
# alive                              0
# alone                              0
# ### Descriptive Statistics ###
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  891.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.361582    0.523008    0.381594
# std       0.486592    0.836071   NaN   13.019697    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   22.000000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   35.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male  embark_town alive alone
# count   891.000000      891    891  891        891          889   891   891
# unique         NaN        3      3    3          2            3     2     2
# top            NaN        S  Third  man       True  Southampton    no  True
# freq           NaN      646    491  537        537          644   549   537
# mean     32.204208      NaN    NaN  NaN        NaN          NaN   NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN          NaN   NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN          NaN   NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN          NaN   NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN          NaN   NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN          NaN   NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN          NaN   NaN   NaN
# ### Data Visualization ###
#
# Histograms for Numerical Features:
# Box Plots for Numerical Features (Outlier Detection Visualization):
# ### Outlier Detection and Removal (using IQR method) ###
#
#
# Column: age
#   Q1: 22.00, Q3: 35.00, IQR: 13.00
#   Lower Bound: 2.50, Upper Bound: 54.50
#   Number of outliers detected: 66
#   Sample outliers:
#     survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 7          0       3    male   2.0      3      1  21.075        S   Third
# 11         1       1  female  58.0      0      0  26.550        S   First
# 15         1       2  female  55.0      0      0  16.000        S  Second
# 16         0       3    male   2.0      4      1  29.125        Q   Third
# 33         0       2    male  66.0      0      0  10.500        S  Second
#
#       who  adult_male  embark_town alive  alone
# 7   child       False  Southampton    no  False
# 11  woman       False  Southampton   yes   True
# 15  woman       False  Southampton   yes   True
# 16  child       False   Queenstown    no  False
# 33    man        True  Southampton    no   True
#   66 rows removed for outliers in 'age'. Remaining rows: 825
#
# Column: fare
#   Q1: 7.90, Q3: 30.07, IQR: 22.17
#   Lower Bound: -25.37, Upper Bound: 63.33
#   Number of outliers detected: 107
#   Sample outliers:
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1          1       1  female  38.0      1      0   71.2833        C  First
# 27         0       1    male  19.0      3      2  263.0000        S  First
# 31         1       1  female  28.0      1      0  146.5208        C  First
# 34         0       1    male  28.0      1      0   82.1708        C  First
# 52         1       1  female  49.0      1      0   76.7292        C  First
#
#       who  adult_male  embark_town alive  alone
# 1   woman       False    Cherbourg   yes  False
# 27    man        True  Southampton    no  False
# 31  woman       False    Cherbourg   yes  False
# 34    man        True    Cherbourg    no  False
# 52  woman       False    Cherbourg   yes  False
#   107 rows removed for outliers in 'fare'. Remaining rows: 718
#
# Column: sibsp
#   Q1: 0.00, Q3: 1.00, IQR: 1.00
#   Lower Bound: -1.50, Upper Bound: 2.50
#   Number of outliers detected: 29
#   Sample outliers:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 24         0       3  female   8.0      3      1  21.0750        S  Third
# 50         0       3    male   7.0      4      1  39.6875        S  Third
# 59         0       3    male  11.0      5      2  46.9000        S  Third
# 63         0       3    male   4.0      3      2  27.9000        S  Third
# 68         1       3  female  17.0      4      2   7.9250        S  Third
#
#       who  adult_male  embark_town alive  alone
# 24  child       False  Southampton    no  False
# 50  child       False  Southampton    no  False
# 59  child       False  Southampton    no  False
# 63  child       False  Southampton    no  False
# 68  woman       False  Southampton   yes  False
#   29 rows removed for outliers in 'sibsp'. Remaining rows: 689
#
# Column: parch
#   Q1: 0.00, Q3: 0.00, IQR: 0.00
#   Lower Bound: 0.00, Upper Bound: 0.00
#   Number of outliers detected: 112
#   Sample outliers:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 25         1       3  female  38.0      1      5  31.3875        S   Third
# 43         1       2  female   3.0      1      2  41.5792        C  Second
#
#       who  adult_male  embark_town alive  alone
# 8   woman       False  Southampton   yes  False
# 10  child       False  Southampton   yes  False
# 13    man        True  Southampton    no  False
# 25  woman       False  Southampton   yes  False
# 43  child       False    Cherbourg   yes  False
#   112 rows removed for outliers in 'parch'. Remaining rows: 577
#
# Total rows before outlier removal: 891
# Total rows after outlier removal: 577
# Number of unique outliers identified across selected columns: 303
#
# Distributions after Outlier Removal:
# ### Saving Cleaned Dataset ###
#
# Cleaned Titanic dataset saved to 'titanic_cleaned.csv'
#
# ### EDA Complete ###
